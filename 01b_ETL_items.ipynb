# %% [markdown]
# ### Extracción de datos Users Items

# %%
import pandas as pd
import numpy as np
import json
import warnings
warnings.filterwarnings("ignore")

# %%
ruta_items = 'data/australian_users_items.json'
import ast

filas_items = []

with open(ruta_items, encoding='utf-8') as f:
    for line in f.readlines():
        try:
            data = json.loads(line)         # Intenta cargar el JSON normalmente
        except json.JSONDecodeError:        # Cambio el 
            data = ast.literal_eval(line)   # Si falla, usa ast.literal_eval() para cargar el JSON inválido
        filas_items.append(data)

df_items = pd.DataFrame(filas_items)
data_user_item1 = df_items.explode(['items'])
data_user_item2 = pd.json_normalize(data_user_item1['items']).set_index(data_user_item1['items'].index)
df_items2= pd.concat([data_user_item2, data_user_item1], axis=1)
df_items2
# Out:
#       item_id                      item_name  playtime_forever  \
# 0          10                 Counter-Strike               6.0
# 0          20          Team Fortress Classic               0.0
# 0          30                  Day of Defeat               7.0
# 0          40             Deathmatch Classic               0.0
# 0          50      Half-Life: Opposing Force               0.0
# ...       ...                            ...               ...
# 88308  373330                    All Is Dust               0.0
# 88308  388490  One Way To Die: Steam Edition               3.0
# 88308  521570          You Have 10 Seconds 2               4.0
# 88308  519140                     Minds Eyes               3.0
# 88309     NaN                            NaN               NaN
#
#        playtime_2weeks            user_id  items_count           steam_id  \
# 0                  0.0  76561197970982479          277  76561197970982479
# ...

# %% [markdown]
# Las columnas del dataframe son las siguientes:
#
# * **item_id:**
# * **item_name:**
# * **playtime_forever:**
# * **playtime_2weeks:**
# * **user_id:**
# * **items_count:**
# * **steam_id:**
# * **user_url:**
# * **items:**

# %% [markdown]
# Eliminamos la columna items, ya que ya fue desanidada y anexada al dataframe

# %%
del df_items2['items']

# %% [markdown]
# Validamos que se haya almacenado correctamente la información al nuevo dataframe

# %%
fila_etiqueta = df_items.loc[1564]
print(fila_etiqueta)
contenido_reviews = df_items.loc[1564, 'items']
print(contenido_reviews)
# Out:
# user_id                                        76561198054978831
# items_count                                                   24
# steam_id                                       76561198054978831
# user_url       http://steamcommunity.com/profiles/76561198054...
# items          [{'item_id': '240', 'item_name': 'Counter-Stri...
# Name: 1564, dtype: object
# ...

# %%
fila_etiqueta = df_items2.loc[1564]
fila_etiqueta
# Out:
#      item_id                   item_name  playtime_forever  playtime_2weeks  \
# 1564     240      Counter-Strike: Source            1786.0              0.0
# 1564    4000                 Garry's Mod           38127.0              0.0
# 1564     550               Left 4 Dead 2             674.0              0.0
# 1564  223530          Left 4 Dead 2 Beta               0.0              0.0
# 1564   57690                   Tropico 4               0.0              0.0
# 1564   11020  TrackMania Nations Forever             113.0              0.0
# 1564   99900              Spiral Knights            1382.0              0.0
# 1564  113420                Fallen Earth               0.0              0.0
# 1564  218230                PlanetSide 2               0.0              0.0
# 1564  230410                    Warframe            5671.0              0.0
# 1564  209870     Blacklight: Retribution              31.0              0.0
# ...

# %% [markdown]
# #### Transformación de datos

# %%
df_items2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5170015 entries, 0 to 88309
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   item_id           object
#  1   item_name         object
#  2   playtime_forever  float64
#  3   playtime_2weeks   float64
#  4   user_id           object
#  5   items_count       int64
#  6   steam_id          object
#  7   user_url          object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 387.2+ MB

# %% [markdown]
# Calculamos la cantidad de valores nulos en el dataframe df_items2

# %%
porcentaje_nulos = df_items2.isnull().sum() / len(df_items2) * 100

df_nulos = pd.DataFrame(porcentaje_nulos, columns=['%_valores_nulos'])
df_nulos['Cantidad_Nulos'] = df_items2.isnull().sum()
df_nulos['Cantidad_NO_Nulos'] = df_items2.count()
df_nulos['Total_Registros'] = len(df_items2)
df_nulos
# Out:
#                   %_valores_nulos  Cantidad_Nulos  Cantidad_NO_Nulos  \
# item_id                  0.325067           16806            5153209
# item_name                0.325067           16806            5153209
# playtime_forever         0.325067           16806            5153209
# playtime_2weeks          0.325067           16806            5153209
# user_id                  0.000000               0            5170015
# items_count              0.000000               0            5170015
# steam_id                 0.000000               0            5170015
# user_url                 0.000000               0            5170015
#
#                   Total_Registros
# item_id                   5170015
# item_name                 5170015
# playtime_forever          5170015
# playtime_2weeks           5170015
# user_id                   5170015
# items_count               5170015
# steam_id                  5170015
# user_url                  5170015

# %% [markdown]
# Eliminamos los registros nulos, ya que representan 0.32% del total

# %%
df_items2 = df_items2.dropna()

# %%
df_items2.shape[0]
# Out:
# 5153209

# %% [markdown]
# Revisamos los duplicados

# %%
duplicados = df_items2[df_items2.duplicated(keep=False)]
duplicados.head()
# Out:
#    item_id                                    item_name  playtime_forever  \
# 17    4000                                  Garry's Mod             269.0
# 17   33910                                       Arma 2             162.0
# 17   33930                  Arma 2: Operation Arrowhead             223.0
# 17  219540  Arma 2: Operation Arrowhead Beta (Obsolete)               0.0
# 17     400                                       Portal             196.0
#
#     playtime_2weeks            user_id  items_count           steam_id  \
# 17              0.0  76561198156664158           59  76561198156664158
# 17              0.0  76561198156664158           59  76561198156664158
# 17              0.0  76561198156664158           59  76561198156664158
# 17              0.0  76561198156664158           59  76561198156664158
# 17              0.0  76561198156664158           59  76561198156664158
#
#                                              user_url
# ...

# %% [markdown]
# Al validar que sean resultados duplicados, observamos que las horas de playtime_forever y item_name son distintas a pesar que todo lo demás es igual, por lo que no se eliminarán.

# %%
user_id = '76561198156664158'

fila_usuario = df_items2.loc[df_items2['user_id'] == user_id]
fila_usuario.head()
# Out:
#    item_id                                    item_name  playtime_forever  \
# 17    4000                                  Garry's Mod             269.0
# 17   33910                                       Arma 2             162.0
# 17   33930                  Arma 2: Operation Arrowhead             223.0
# 17  219540  Arma 2: Operation Arrowhead Beta (Obsolete)               0.0
# 17     400                                       Portal             196.0
#
#     playtime_2weeks            user_id  items_count           steam_id  \
# 17              0.0  76561198156664158           59  76561198156664158
# 17              0.0  76561198156664158           59  76561198156664158
# 17              0.0  76561198156664158           59  76561198156664158
# 17              0.0  76561198156664158           59  76561198156664158
# 17              0.0  76561198156664158           59  76561198156664158
#
#                                              user_url
# ...

# %% [markdown]
# Eliminamos las columnas que no se utilizarán: playtime_2weeks, user_url

# %%
eliminar = ['playtime_2weeks', 'user_url']
df_items2 = df_items2.drop(columns=eliminar)

# %% [markdown]
# Ya que contamos con el dataframe limpio, proseguimos con la modificación del tipo de dato de cada columna

# %%
df_items2['user_id'] = df_items2['user_id'].astype(str)
df_items2['item_name'] = df_items2['item_name'].astype(str)
df_items2['user_id'] = df_items2['user_id'].astype(str)

# %% [markdown]
# Guardamos el conjunto ya limpio a un csv

# %%
df_items2.to_csv('users_items_cleaned.csv', index = False, encoding='utf-8')

# %% [markdown]
# Este es el fin de esta parte del proceso, porfavor da click [aqui](01c_ETL_reviews.ipynb) para continuar.
