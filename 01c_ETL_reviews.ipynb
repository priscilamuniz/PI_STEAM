# %% [markdown]
# ### Extracción de datos users_reviews

# %% [markdown]
# Importamos las bibliotecas a utilizar

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
import warnings
from datetime import datetime
warnings.filterwarnings("ignore")

# %% [markdown]
# Extraemos los datos de los datasets

# %%
ruta_review = 'data/australian_user_reviews.json'
import ast

filas_review = []

with open(ruta_review, encoding='utf-8') as f:
    for line in f.readlines():
        try:
            data = json.loads(line)         # Intenta cargar el JSON normalmente
        except json.JSONDecodeError:        # Si tiene error: 
            data = ast.literal_eval(line)   # Usa ast.literal_eval() para cargar el JSON inválido y cambiar '' por ""
        filas_review.append(data)           # agrega la linea corregida a la lista

df_review = pd.DataFrame(filas_review)      # una vez cargados todas las lineas a la lista, hace un DataFrame con dicha lista
df_review                                   # validamos el DataFrame
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# 0      [{'funny': '', 'posted': 'Posted November 5, 2...
# 1      [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2      [{'funny': '', 'posted': 'Posted February 3.',...
# 3      [{'funny': '', 'posted': 'Posted October 14, 2...
# 4      [{'funny': '3 people found this review funny',...
# ...                                                  ...
# 25794  [{'funny': '', 'posted': 'Posted May 31.', 'la...
# 25795  [{'funny': '', 'posted': 'Posted June 17.', 'l...
# 25796  [{'funny': '1 person found this review funny',...
# 25797  [{'funny': '', 'posted': 'Posted July 21.', 'l...
# 25798  [{'funny': '1 person found this review funny',...
#
# [25799 rows x 3 columns]

# %% [markdown]
# Las columnas del dataframe son las siguientes:
# * **user_id:** es un identificador único para el usuario.
# * **user_url:** es la url del perfil del usuario en streamcommunity.
# * **reviews:** contiene una lista de diccionarios. Para cada usuario se tiene uno o mas diccionario con el review.

# %% [markdown]
# De la columna reviews, sacamos la informacion de los diccionarios

# %%
df_clean_reviews = df_review.explode('reviews') 

# Unimos el dataframe con user ir y url, con el que acabamos de extraer la información de los diccionarios de la columna review

df_reviews2 = pd.concat([df_clean_reviews.drop(['reviews'], axis=1), df_clean_reviews['reviews'].apply(pd.Series)], axis=1)     

# elimina la columna 'reviews' del DataFrame df_clean_reviews y expande la columna 'reviews' en varios campos (si cada elemento # de la columna 'reviews' contiene varios valores) para luego unir esta información 
# en un nuevo DataFrame df_reviews2

# %%
df_reviews2.head(10)
# Out:
#              user_id                                           user_url funny  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 1            js41637               http://steamcommunity.com/id/js41637
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 2          evcentric             http://steamcommunity.com/id/evcentric
#
#                       posted                    last_edited item_id  \
# 0   Posted November 5, 2011.                                   1250
# 0      Posted July 15, 2011.                                  22200
# 0     Posted April 21, 2011.                                  43110
# 1      Posted June 24, 2014.                                 251610
# 1  Posted September 8, 2013.                                 227300
# 1  Posted November 29, 2013.                                 239030
# 2         Posted February 3.                                 248820
# 2   Posted December 4, 2015.  Last edited December 5, 2015.  370360
# 2   Posted November 3, 2014.                                 237930
# 2   Posted October 15, 2014.                                 263360
#
#                                            helpful recommend  \
# 0                                   No ratings yet      True
# 0                                   No ratings yet      True
# 0                                   No ratings yet      True
# 1  15 of 20 people (75%) found this review helpful      True
# 1     0 of 1 people (0%) found this review helpful      True
# 1    1 of 4 people (25%) found this review helpful      True
# 2                                   No ratings yet      True
# 2                                   No ratings yet      True
# 2                                   No ratings yet      True
# 2                                   No ratings yet      True
#
#                                               review   0
# 0  Simple yet with great replayability. In my opi... NaN
# 0               It's unique and worth a playthrough. NaN
# 0  Great atmosphere. The gunplay can be a bit chu... NaN
# 1  I know what you think when you see this title ... NaN
# 1  For a simple (it's actually not all that simpl... NaN
# 1  Very fun little game to play when your bored o... NaN
# 2  A suitably punishing roguelike platformer.  Wi... NaN
# 2  "Run for fun? What the hell kind of fun is that?" NaN
# 2  Elegant integration of gameplay, story, world ... NaN
# 2  Random drops and random quests, with stat poin... NaN

# %%
del df_reviews2[0]      # eliminamos la columna de NaN que se creó

# %% [markdown]
# Las columnas resultantes de normalizar la columna reviews son las siguientes:
#
# * **funny:** indica si alguien puso emoticón de gracioso al review.
# * **posted:** es la fecha de posteo del review en formato Posted April 21, 2011.
# * **last_edited:** es la fecha de la última edición.
# * **item_id:** es el identificador único del item, es decir, del juego.
# * **helpful:** es la estadística donde otros usuarios indican si fue útil la información.
# * **recommend:** es un booleano que indica si el usuario recomienda o no el juego.
# * **review:** es una sentencia string con los comentarios sobre el juego.

# %% [markdown]
# Validamos que se haya almacenado correctamente la informacion al nuevo dataframe

# %%
fila_etiqueta = df_review.loc[1564]
print(fila_etiqueta)
contenido_reviews = df_review.loc[1564, 'reviews']
print(contenido_reviews)
# Out:
# user_id                                     76561198056300439
# user_url    http://steamcommunity.com/profiles/76561198056...
# reviews     [{'funny': '1 person found this review funny',...
# Name: 1564, dtype: object
# [{'funny': '1 person found this review funny', 'posted': 'Posted April 26, 2015.', 'last_edited': '', 'item_id': '730', 'helpful': '0 of 1 people (0%) found this review helpful', 'recommend': False, 'review': '♥♥♥♥ING ♥♥♥♥ OF COMPETITIVE MATCHESTHIS ♥♥♥♥ING ♥♥♥♥ FIND GAMES THAT MY TEAM HAS ♥♥♥♥ING 20 HOURS OF GAME, AND I HAVE 700, ♥♥♥♥ THIS ♥♥♥♥, NEVER GOT ONE GOOD TEAM ON THIS ♥♥♥♥ING FREAKING ♥♥♥♥♥♥♥♥♥♥♥♥ GAME'}, {'funny': '', 'posted': 'Posted January 17.', 'last_edited': '', 'item_id': '304240', 'helpful': 'No ratings yet', 'recommend': True, 'review': 'Best Game ever'}, {'funny': '', 'posted': 'Posted May 10, 2014.', 'last_edited': '', 'item_id': '238320', 'helpful': 'No ratings yet', 'recommend': True, 'review': "Well what can i say about this game?It's the BEST SURVIVAL HORROR GAME EVER!!!!!!!The environment is perfect, the scares are perfectsYou can feel the game when you play itJust Awesome"}, {'funny': '', 'posted': 'Posted May 10, 2014.', 'last_edited': '', 'item_id': '225260', 'helpful': 'No ratings yet', 'recommend': True, 'review': "This Game Is AWESOME!!!It's very fun to play it, if you want a good game to past the time, this game is perfect, its not hard to play  and it entertains youSimple controls and very nice to play with a gamepadBut if you don't like rock / metal , don't spend your money, cause this game will rocks you!!!!!"}]

# %%
fila_etiqueta = df_reviews2.loc[1564]
fila_etiqueta
# Out:
#                 user_id                                           user_url  \
# 1564  76561198056300439  http://steamcommunity.com/profiles/76561198056...
# 1564  76561198056300439  http://steamcommunity.com/profiles/76561198056...
# 1564  76561198056300439  http://steamcommunity.com/profiles/76561198056...
# 1564  76561198056300439  http://steamcommunity.com/profiles/76561198056...
#
#                                  funny                  posted last_edited  \
# 1564  1 person found this review funny  Posted April 26, 2015.
# 1564                                        Posted January 17.
# 1564                                      Posted May 10, 2014.
# 1564                                      Posted May 10, 2014.
#
#      item_id                                       helpful recommend  \
# 1564     730  0 of 1 people (0%) found this review helpful     False
# 1564  304240                                No ratings yet      True
# 1564  238320                                No ratings yet      True
# 1564  225260                                No ratings yet      True
#
#                                                  review
# 1564  ♥♥♥♥ING ♥♥♥♥ OF COMPETITIVE MATCHESTHIS ♥♥♥♥IN...
# 1564                                     Best Game ever
# 1564  Well what can i say about this game?It's the B...
# 1564  This Game Is AWESOME!!!It's very fun to play i...

# %% [markdown]
# #### Transformación de datos

# %%
df_reviews2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59333 entries, 0 to 25798
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      59333 non-null  object
#  1   user_url     59333 non-null  object
#  2   funny        59305 non-null  object
#  3   posted       59305 non-null  object
#  4   last_edited  59305 non-null  object
#  5   item_id      59305 non-null  object
#  6   helpful      59305 non-null  object
#  7   recommend    59305 non-null  object
#  8   review       59305 non-null  object
# dtypes: object(9)
# memory usage: 6.5+ MB

# %% [markdown]
# Calculamos la cantidad de valores nulos en el DataFrame df_reviews2

# %%
porcentaje_nulos = df_reviews2.isnull().sum() / len(df_reviews2) * 100

df_nulos = pd.DataFrame(porcentaje_nulos, columns=['%_valores_nulos'])
df_nulos['Cantidad_Nulos'] = df_reviews2.isnull().sum()
df_nulos['Cantidad_NO_Nulos'] = df_reviews2.count()
df_nulos['Total_Registros'] = len(df_reviews2)
df_nulos
# Out:
#              %_valores_nulos  Cantidad_Nulos  Cantidad_NO_Nulos  \
# user_id             0.000000               0              59333
# user_url            0.000000               0              59333
# funny               0.047191              28              59305
# posted              0.047191              28              59305
# last_edited         0.047191              28              59305
# item_id             0.047191              28              59305
# helpful             0.047191              28              59305
# recommend           0.047191              28              59305
# review              0.047191              28              59305
#
#              Total_Registros
# user_id                59333
# user_url               59333
# funny                  59333
# posted                 59333
# last_edited            59333
# item_id                59333
# helpful                59333
# recommend              59333
# review                 59333

# %% [markdown]
# Calculamos la cantidad de registros totalmente nulos, y procedemos a eliminarlos

# %%
cantidad_filas_nulas = df_reviews2.isnull().all(axis=1).sum()
print("Cantidad de filas con todos los valores nulos:", cantidad_filas_nulas)
if cantidad_filas_nulas > 0:
    df_reviews2 = df_reviews2.dropna(how='all').reset_index(drop=True)
    print('Se eliminaron los registros totalmente vacios')
else:
    print('No se eliminó registros, ya que no se encontraron registros totalmente vacios')
# Out:
# Cantidad de filas con todos los valores nulos: 0
# No se eliminó registros, ya que no se encontraron registros totalmente vacios

# %% [markdown]
# Eliminamos los registros nulos

# %%
df_reviews2 = df_reviews2.dropna()

# %% [markdown]
# La columna funny tiene un 86% de celdas vacías (no nulas), por lo que procedemos a eliminarla del df

# %%
vacios = pd.DataFrame(df_reviews2['funny'].value_counts() / len(df_reviews2) * 100)
vacios = vacios.rename(columns={'count': '%Vacios'})
vacios
# Out:
#                                         %Vacios
# funny
#                                       86.255796
# 1 person found this review funny       8.734508
# 2 people found this review funny       2.077397
# 3 people found this review funny       0.827923
# 4 people found this review funny       0.450215
# ...                                         ...
# 58 people found this review funny      0.001686
# 405 people found this review funny     0.001686
# 105 people found this review funny     0.001686
# 1,130 people found this review funny   0.001686
# 825 people found this review funny     0.001686
#
# [186 rows x 1 columns]

# %%
df_reviews2 = df_reviews2.drop('funny', axis=1)

# %% [markdown]
# Sucede lo mismo con last_edited

# %%
vacios = pd.DataFrame(df_reviews2['last_edited'].value_counts() / len(df_reviews2) * 100)
vacios = vacios.rename(columns={'count': '%Vacios'})
vacios
# Out:
#                                   %Vacios
# last_edited
#                                 89.646741
# Last edited November 25, 2013.   0.166934
# Last edited October 17, 2015.    0.032038
# Last edited June 6, 2015.        0.030352
# Last edited January 3.           0.028665
# ...                                   ...
# Last edited May 30, 2015.        0.001686
# Last edited May 21, 2015.        0.001686
# Last edited February 11, 2014.   0.001686
# Last edited May 8, 2014.         0.001686
# Last edited August 15, 2014.     0.001686
#
# [1015 rows x 1 columns]

# %% [markdown]
# Eliminamos la columna

# %%
df_reviews2 = df_reviews2.drop('last_edited', axis=1)

# %% [markdown]
# Revisamos los duplicados

# %%
filas_duplicadas = df_reviews2[df_reviews2.duplicated(keep='first')]
filas_duplicadas.head()
# Out:
#          user_id                                 user_url  \
# 456   bokkkbokkk  http://steamcommunity.com/id/bokkkbokkk
# 1182  ImSeriouss  http://steamcommunity.com/id/ImSeriouss
# 1182  ImSeriouss  http://steamcommunity.com/id/ImSeriouss
# 1182  ImSeriouss  http://steamcommunity.com/id/ImSeriouss
# 1182  ImSeriouss  http://steamcommunity.com/id/ImSeriouss
#
#                           posted item_id  \
# 456   Posted September 24, 2015.  346110
# 1182    Posted January 10, 2014.  218620
# 1182    Posted January 10, 2014.  105600
# 1182   Posted December 17, 2014.     570
# 1182    Posted January 13, 2014.  211820
#
#                                              helpful recommend  \
# 456   1 of 1 people (100%) found this review helpful      True
# 1182   1 of 3 people (33%) found this review helpful      True
# 1182    0 of 2 people (0%) found this review helpful      True
# 1182                                  No ratings yet      True
# 1182                                  No ratings yet      True
#
#                                                  review
# 456                                                 yep
# 1182             Good graphics, fun heists! A bit laggy
# 1182  So fun! DEFINITELY NOT RIP OFF OF MINECRAFT! e...
# 1182                                         bobo pinoy
# 1182  If you want to play this game.. expect glithes...

# %% [markdown]
# Al validar que sean resultados duplicados, observamos que realmente no son registros duplicados por lo que no se eliminarán.

# %%
user_id = 'ImSeriouss'

fila_usuario = df_reviews2.loc[df_reviews2['user_id'] == user_id]
fila_usuario.head()
# Out:
#          user_id                                 user_url  \
# 1181  ImSeriouss  http://steamcommunity.com/id/ImSeriouss
# 1181  ImSeriouss  http://steamcommunity.com/id/ImSeriouss
# 1181  ImSeriouss  http://steamcommunity.com/id/ImSeriouss
# 1181  ImSeriouss  http://steamcommunity.com/id/ImSeriouss
# 1181  ImSeriouss  http://steamcommunity.com/id/ImSeriouss
#
#                          posted item_id  \
# 1181   Posted January 10, 2014.  218620
# 1181   Posted January 10, 2014.  105600
# 1181  Posted December 17, 2014.     570
# 1181   Posted January 13, 2014.  211820
# 1181   Posted January 10, 2014.     440
#
#                                             helpful recommend  \
# 1181  1 of 3 people (33%) found this review helpful      True
# 1181   0 of 2 people (0%) found this review helpful      True
# 1181                                 No ratings yet      True
# 1181                                 No ratings yet      True
# 1181                                 No ratings yet      True
#
#                                                  review
# 1181             Good graphics, fun heists! A bit laggy
# 1181  So fun! DEFINITELY NOT RIP OFF OF MINECRAFT! e...
# 1181                                         bobo pinoy
# 1181  If you want to play this game.. expect glithes...
# 1181  Really good game! fun! Good for people who wan...

# %% [markdown]
# Para simplificar el dataframe, agregaremos la columna year_posted la cual contiene únicamente el año, para su posterior análisis

# %%
df_reviews2['year_posted'] = df_reviews2['posted'].str.extract(r'(\d{4})')          # extraemos el año
media = df_reviews2['year_posted'].dropna().astype(float).median()                  # como son más de 10,000 datos que no cuentan con el dato del año
df_reviews2['year_posted'] = df_reviews2['year_posted'].fillna(media)               # rellenamos esos nulos con la media de los años con de los que si tienen el dato del year_posted

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Analisis de sentimientos

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %% [markdown]
# REVISAR EL IDIOMA DE LOS REVIEWS

# %%
contador_idiomas = {}

for resenia in data_reviews['review']:
    idioma,_ = langid.classify(resenia)
    contador_idiomas[idioma] = contador_idiomas.get(idioma,0) + 1

# %% [markdown]
# ##### VADER

# %%
res = {}                                                                    # isntanciamos un diccionario vacio para almacenar los resultados
for i, linea in tqdm(df_reviews2.iterrows(), total=len(df_reviews2)):       # iteramos en todas las lineas del df 
    text = linea['review']
    myid = linea['user_id']
    res[myid] = sia.polarity_scores(text)                                   # para determinar su polarity score
# Out:
#   0%|          | 0/59305 [00:00<?, ?it/s]

# %%
vaders = pd.DataFrame(res).T                                                 # Resultados del análisis, que tan negativo, positivo o neutral es el review
#vaders = vaders.reset_index().rename(columns={'index':'users_id'})
# Suponiendo que 'user_id' es la columna que identifica a los usuarios en ambos DataFrames
merged_df = vaders.merge(df_reviews2, left_index=True, right_on='user_id', how='left')
merged_df
# Out:
#          neg    neu    pos  compound            user_id  \
# 0      0.000  0.704  0.296    0.9117  76561197970982479
# 0      0.000  0.704  0.296    0.9117  76561197970982479
# 0      0.000  0.704  0.296    0.9117  76561197970982479
# 1      0.081  0.541  0.378    0.7713            js41637
# 1      0.081  0.541  0.378    0.7713            js41637
# ...      ...    ...    ...       ...                ...
# 25797  0.026  0.692  0.282    0.9786  76561198312638244
# 25797  0.026  0.692  0.282    0.9786  76561198312638244
# 25798  0.000  0.203  0.797    0.8349        LydiaMorley
# 25798  0.000  0.203  0.797    0.8349        LydiaMorley
# 25798  0.000  0.203  0.797    0.8349        LydiaMorley
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 0      http://steamcommunity.com/profiles/76561197970...
# 0      http://steamcommunity.com/profiles/76561197970...
# 1                   http://steamcommunity.com/id/js41637
# 1                   http://steamcommunity.com/id/js41637
# ...                                                  ...
# 25797  http://steamcommunity.com/profiles/76561198312...
# 25797  http://steamcommunity.com/profiles/76561198312...
# 25798           http://steamcommunity.com/id/LydiaMorley
# 25798           http://steamcommunity.com/id/LydiaMorley
# 25798           http://steamcommunity.com/id/LydiaMorley
#
#                           posted item_id  \
# 0       Posted November 5, 2011.    1250
# 0          Posted July 15, 2011.   22200
# 0         Posted April 21, 2011.   43110
# 1          Posted June 24, 2014.  251610
# 1      Posted September 8, 2013.  227300
# ...                          ...     ...
# 25797            Posted July 10.      70
# 25797             Posted July 8.  362890
# 25798             Posted July 3.  273110
# 25798            Posted July 20.     730
# 25798             Posted July 2.     440
#
#                                                helpful recommend  \
# 0                                       No ratings yet      True
# 0                                       No ratings yet      True
# 0                                       No ratings yet      True
# 1      15 of 20 people (75%) found this review helpful      True
# 1         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 25797                                   No ratings yet      True
# 25797                                   No ratings yet      True
# 25798    1 of 2 people (50%) found this review helpful      True
# 25798                                   No ratings yet      True
# 25798                                   No ratings yet      True
#
#                                                   review year_posted
# 0      Simple yet with great replayability. In my opi...        2011
# 0                   It's unique and worth a playthrough.        2011
# 0      Great atmosphere. The gunplay can be a bit chu...        2011
# 1      I know what you think when you see this title ...        2014
# 1      For a simple (it's actually not all that simpl...        2013
# ...                                                  ...         ...
# 25797  a must have classic from steam definitely wort...      2014.0
# 25797  this game is a perfect remake of the original ...      2014.0
# 25798  had so much fun plaing this and collecting res...      2014.0
# 25798                                                 :D      2014.0
# 25798                                     so much fun :D      2014.0
#
# [59305 rows x 12 columns]

# %% [markdown]
# Validamos que se haya realizado correctamente el merge

# %%
fila = df_reviews2.loc[df_reviews2['user_id'] == 'js41637']
fila
# Out:
#    user_id                              user_url                     posted  \
# 1  js41637  http://steamcommunity.com/id/js41637      Posted June 24, 2014.
# 1  js41637  http://steamcommunity.com/id/js41637  Posted September 8, 2013.
# 1  js41637  http://steamcommunity.com/id/js41637  Posted November 29, 2013.
#
#   item_id                                          helpful recommend  \
# 1  251610  15 of 20 people (75%) found this review helpful      True
# 1  227300     0 of 1 people (0%) found this review helpful      True
# 1  239030    1 of 4 people (25%) found this review helpful      True
#
#                                               review year_posted
# 1  I know what you think when you see this title ...        2014
# 1  For a simple (it's actually not all that simpl...        2013
# 1  Very fun little game to play when your bored o...        2013

# %% [markdown]
# Hacemos la ponderacion:
# * 0 si es Malo
# * 1 si es Neutral
# * 2 si es Bueno

# %%
merged_df['score'] = 1

# Iterar sobre las filas y actualizar la columna 'score' basada en la puntuación compuesta ('compound')
for index, row in merged_df.iterrows():
    if row['compound'] > 0:
        merged_df.at[index, 'score'] = 2
    elif row['compound'] < 0:
        merged_df.at[index, 'score'] = 0

# %%
merged_df
# Out:
#          neg    neu    pos  compound            user_id  \
# 0      0.000  0.704  0.296    0.9117  76561197970982479
# 0      0.000  0.704  0.296    0.9117  76561197970982479
# 0      0.000  0.704  0.296    0.9117  76561197970982479
# 1      0.081  0.541  0.378    0.7713            js41637
# 1      0.081  0.541  0.378    0.7713            js41637
# ...      ...    ...    ...       ...                ...
# 25797  0.026  0.692  0.282    0.9786  76561198312638244
# 25797  0.026  0.692  0.282    0.9786  76561198312638244
# 25798  0.000  0.203  0.797    0.8349        LydiaMorley
# 25798  0.000  0.203  0.797    0.8349        LydiaMorley
# 25798  0.000  0.203  0.797    0.8349        LydiaMorley
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 0      http://steamcommunity.com/profiles/76561197970...
# 0      http://steamcommunity.com/profiles/76561197970...
# 1                   http://steamcommunity.com/id/js41637
# 1                   http://steamcommunity.com/id/js41637
# ...                                                  ...
# 25797  http://steamcommunity.com/profiles/76561198312...
# 25797  http://steamcommunity.com/profiles/76561198312...
# 25798           http://steamcommunity.com/id/LydiaMorley
# 25798           http://steamcommunity.com/id/LydiaMorley
# 25798           http://steamcommunity.com/id/LydiaMorley
#
#                           posted item_id  \
# 0       Posted November 5, 2011.    1250
# 0          Posted July 15, 2011.   22200
# 0         Posted April 21, 2011.   43110
# 1          Posted June 24, 2014.  251610
# 1      Posted September 8, 2013.  227300
# ...                          ...     ...
# 25797            Posted July 10.      70
# 25797             Posted July 8.  362890
# 25798             Posted July 3.  273110
# 25798            Posted July 20.     730
# 25798             Posted July 2.     440
#
#                                                helpful recommend  \
# 0                                       No ratings yet      True
# 0                                       No ratings yet      True
# 0                                       No ratings yet      True
# 1      15 of 20 people (75%) found this review helpful      True
# 1         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 25797                                   No ratings yet      True
# 25797                                   No ratings yet      True
# 25798    1 of 2 people (50%) found this review helpful      True
# 25798                                   No ratings yet      True
# 25798                                   No ratings yet      True
#
#                                                   review year_posted  score
# 0      Simple yet with great replayability. In my opi...        2011      2
# 0                   It's unique and worth a playthrough.        2011      2
# 0      Great atmosphere. The gunplay can be a bit chu...        2011      2
# 1      I know what you think when you see this title ...        2014      2
# 1      For a simple (it's actually not all that simpl...        2013      2
# ...                                                  ...         ...    ...
# 25797  a must have classic from steam definitely wort...      2014.0      2
# 25797  this game is a perfect remake of the original ...      2014.0      2
# 25798  had so much fun plaing this and collecting res...      2014.0      2
# 25798                                                 :D      2014.0      2
# 25798                                     so much fun :D      2014.0      2
#
# [59305 rows x 13 columns]

# %% [markdown]
# Validamos que haya funcionado correctamente

# %%
score = merged_df.loc[merged_df['score'] == 1]
score
# Out:
#        neg  neu  pos  compound            user_id  \
# 6      0.0  1.0  0.0       0.0  76561198079601835
# 8      0.0  1.0  0.0       0.0  76561198089393905
# 8      0.0  1.0  0.0       0.0  76561198089393905
# 10     0.0  1.0  0.0       0.0  76561198077246154
# 10     0.0  1.0  0.0       0.0  76561198077246154
# ...    ...  ...  ...       ...                ...
# 25777  0.0  1.0  0.0       0.0         3214213216
# 25784  0.0  1.0  0.0       0.0  76561198272389051
# 25787  0.0  1.0  0.0       0.0             943525
# 25791  0.0  1.0  0.0       0.0            sexyawp
# 25795  0.0  1.0  0.0       0.0           Ghoustik
#
#                                                 user_url  \
# 6      http://steamcommunity.com/profiles/76561198079...
# 8      http://steamcommunity.com/profiles/76561198089...
# 8      http://steamcommunity.com/profiles/76561198089...
# 10     http://steamcommunity.com/profiles/76561198077...
# 10     http://steamcommunity.com/profiles/76561198077...
# ...                                                  ...
# 25777            http://steamcommunity.com/id/3214213216
# 25784  http://steamcommunity.com/profiles/76561198272...
# 25787                http://steamcommunity.com/id/943525
# 25791               http://steamcommunity.com/id/sexyawp
# 25795              http://steamcommunity.com/id/Ghoustik
#
#                          posted item_id  \
# 6                Posted May 20.     730
# 8      Posted February 1, 2015.   72850
# 8         Posted June 20, 2014.     440
# 10              Posted June 11.     440
# 10      Posted August 25, 2014.  304930
# ...                         ...     ...
# 25777        Posted February 7.     240
# 25784           Posted June 17.     440
# 25787           Posted March 5.  298110
# 25791          Posted April 25.  427730
# 25795           Posted June 17.     730
#
#                                               helpful recommend  \
# 6        0 of 1 people (0%) found this review helpful      True
# 8      3 of 3 people (100%) found this review helpful      True
# 8      3 of 3 people (100%) found this review helpful      True
# 10                                     No ratings yet      True
# 10                                     No ratings yet      True
# ...                                               ...       ...
# 25777    0 of 2 people (0%) found this review helpful      True
# 25784  1 of 1 people (100%) found this review helpful      True
# 25787                                  No ratings yet     False
# 25791   1 of 2 people (50%) found this review helpful      True
# 25795    0 of 1 people (0%) found this review helpful      True
#
#                                                   review year_posted  score
# 6                                          ZIKA DO BAILE      2014.0      1
# 8      Killed the Emperor, nobody cared and got away ...        2015      1
# 8           10/10 would eat your money for hats and keys        2014      1
# 10                                                mt bom      2014.0      1
# 10                                           É muito bom        2014      1
# ...                                                  ...         ...    ...
# 25777                                               잼꾸르잼      2014.0      1
# 25784                       Hi I don't know what this is      2014.0      1
# 25787                                   uplay, everytime      2014.0      1
# 25791                                           dont ask      2014.0      1
# 25795  Gra naprawdę fajna.Ale jest kilka rzeczy do kt...      2014.0      1
#
# [11668 rows x 13 columns]

# %% [markdown]
# Eliminamos las columnas que ya no se necesitan: neg, neu, pos, compound, posted, review

# %%
eliminar = ['neg','neu','pos','compound','review','posted', 'user_url', 'helpful']
merged_df = merged_df.drop(columns=eliminar)

# %%
merged_df.head()
# Out:
#              user_id item_id recommend year_posted  score
# 0  76561197970982479    1250      True        2011      2
# 0  76561197970982479   22200      True        2011      2
# 0  76561197970982479   43110      True        2011      2
# 1            js41637  251610      True        2014      2
# 1            js41637  227300      True        2013      2

# %% [markdown]
# Modificamos la columna recommend, donde
# False = 0
# True = 1

# %% [markdown]
# Validamos antes del cambio, cuantos True y False hay

# %%
merged_df['recommend'].value_counts()
# Out:
# recommend
# True     52473
# False     6832
# Name: count, dtype: int64

# %% [markdown]
# Realizamos el cambio

# %%
merged_df['recommend'] = merged_df['recommend'].replace({False: 0, True: 1})
merged_df
# Out:
#                  user_id item_id  recommend year_posted  score
# 0      76561197970982479    1250          1        2011      2
# 0      76561197970982479   22200          1        2011      2
# 0      76561197970982479   43110          1        2011      2
# 1                js41637  251610          1        2014      2
# 1                js41637  227300          1        2013      2
# ...                  ...     ...        ...         ...    ...
# 25797  76561198312638244      70          1      2014.0      2
# 25797  76561198312638244  362890          1      2014.0      2
# 25798        LydiaMorley  273110          1      2014.0      2
# 25798        LydiaMorley     730          1      2014.0      2
# 25798        LydiaMorley     440          1      2014.0      2
#
# [59305 rows x 5 columns]

# %% [markdown]
# Validamos que no se haya modificado la cantidad de True y False

# %%
merged_df['recommend'].value_counts()
# Out:
# recommend
# 1    52473
# 0     6832
# Name: count, dtype: int64

# %% [markdown]
# Ya que contamos con el dataframe limpio, procedemos con la modificación de los tipos de datos de cada columna que haga falta

# %%
merged_df['user_id'] = merged_df['user_id'].astype(str)
merged_df['year_posted'] = merged_df['year_posted'].astype(int)

# %% [markdown]
# Guardamos el conjunto ya limpio a un csv

# %%
merged_df.to_csv('users_reviews_cleaned.csv', index = False, encoding='utf-8')

# %% [markdown]
# Este es el fin de esta parte del proceso, porfavor da click [aqui](02_Funciones.ipynb) para continuar.
